# %% [markdown]
# # Opening Images in OpenCV

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img  = cv2.imread('cat.jpg')

# %%
type(img) 
# in case in image file is not passed it shows none type imread does not give error so important to check the image type
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (183, 275, 3)

# %%
plt.imshow(img);
# default color is bgr for opencv but rgb for matplotlib

# %%
img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb);

# %%
img_gray = cv2.cvtColor(img,cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray);
# using cv2.IMREAD_GRAYSCALE on cvtColor increases the dimension instead of truncating it

# %%
img_gray.shape
# Out:
# (183, 275, 4)

# %%
img_gray_1 = cv2.imread('cat.jpg',cv2.IMREAD_GRAYSCALE) # opening using imread fresh reading
plt.imshow(img_gray,cmap = 'gray');

# %%
img_gray_1.shape
# Out:
# (183, 275)

# %% [markdown]
# ## Resize Images

# %%
img_rgb.shape
# Out:
# (183, 275, 3)

# %%
img = cv2.resize(img_rgb,(200,183))
# img_rgb contains h,w,color channels while resize function takes w,h,c
plt.imshow(img);

# %% [markdown]
# ## By ratio

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
new_img = cv2.resize(img_rgb,(0,0),img_rgb,w_ratio,h_ratio)

# %%
plt.imshow(new_img);
# check dimension to see if size change is implemented or not

# %% [markdown]
# ## Flipping Images

# %%
new_img = cv2.flip(new_img,0)
plt.imshow(new_img);
# 0 is flipping along x axis

# %%
new_img = cv2.flip(new_img,1)
plt.imshow(new_img);
# 1 is flipping along y axis

# %%
new_img = cv2.flip(new_img,-1)
plt.imshow(new_img);
# -1 is flipping along both axes

# %% [markdown]
# ## Saving Image Files

# %%
type(new_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('new_cat.jpg',new_img)
# Storing BGR version of the image effectively as it was initially changed
# Out:
# True

# %% [markdown]
# ## Larger Display in Notebook

# %%
fig = plt.figure(figsize = (15,10))
ax = fig.add_subplot(111) # 1x1 grid 1st subplot
ax.imshow(new_img);

# %%
fig = plt.figure()
fig.add_subplot(1, 2, 1)   #top and bottom left
fig.add_subplot(2, 2, 2)   #top right
fig.add_subplot(2, 2, 4)   #bottom right 
plt.show()

# %%
fig = plt.figure()
fig.add_subplot(2, 2, 4)   #bottom right 
plt.show()
